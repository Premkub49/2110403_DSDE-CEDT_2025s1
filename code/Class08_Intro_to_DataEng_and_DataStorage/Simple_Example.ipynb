# %% [markdown]
# # Simple Redis-Py Example
# This notebook contains simple redis python commands.

# %%
import redis

# %% [markdown]
# Connect to local server -- no hostname or ip is needed

# %%
rd = redis.Redis(charset="utf-8", decode_responses=True)

# %%
rd.set('user:101:name', 'pinot')
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File ~/.conda/envs/dsde-cedt/lib/python3.10/site-packages/redis/connection.py:855, in AbstractConnection.connect_check_health(self, check_health, retry_socket_connect)
#     854 if retry_socket_connect:
# --> 855     sock = self.retry.call_with_retry(
#     856         lambda: self._connect(), lambda error: self.disconnect(error)
#     857     )
#     858 else:
#
# File ~/.conda/envs/dsde-cedt/lib/python3.10/site-packages/redis/retry.py:116, in Retry.call_with_retry(self, do, fail, is_retryable)
#     115 try:
# --> 116     return do()
#     117 except self._supported_errors as error:
#
# File ~/.conda/envs/dsde-cedt/lib/python3.10/site-packages/redis/connection.py:856, in AbstractConnection.connect_check_health.<locals>.<lambda>()
#     854 if retry_socket_connect:
#     855     sock = self.retry.call_with_retry(
# --> 856         lambda: self._connect(), lambda error: self.disconnect(error)
#     857     )
#     858 else:
#
# File ~/.conda/envs/dsde-cedt/lib/python3.10/site-packages/redis/connection.py:1306, in Connection._connect(self)
#    1305 if err is not None:
# -> 1306     raise err
#    1307 raise OSError("socket.getaddrinfo returned an empty list")
#
# File ~/.conda/envs/dsde-cedt/lib/python3.10/site-packages/redis/connection.py:1290, in Connection._connect(self)
#    1289 # connect
# -> 1290 sock.connect(socket_address)
#    1292 # set the socket_timeout now that we're connected
#
# ConnectionRefusedError: [Errno 111] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 rd.set('user:101:name', 'pinot')
#
# File ~/.conda/envs/dsde-cedt/lib/python3.10/site-packages/redis/commands/core.py:2310, in BasicKeyCommands.set(self, name, value, ex, px, nx, xx, keepttl, get, exat, pxat)
#    2307     pieces.append("GET")
#    2308     options["get"] = True
# -> 2310 return self.execute_command("SET", *pieces, **options)
#
# File ~/.conda/envs/dsde-cedt/lib/python3.10/site-packages/redis/client.py:657, in Redis.execute_command(self, *args, **options)
#     656 def execute_command(self, *args, **options):
# --> 657     return self._execute_command(*args, **options)
#
# File ~/.conda/envs/dsde-cedt/lib/python3.10/site-packages/redis/client.py:663, in Redis._execute_command(self, *args, **options)
#     661 pool = self.connection_pool
#     662 command_name = args[0]
# --> 663 conn = self.connection or pool.get_connection()
#     665 if self._single_connection_client:
#     666     self.single_connection_lock.acquire()
#
# File ~/.conda/envs/dsde-cedt/lib/python3.10/site-packages/redis/utils.py:196, in deprecated_args.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     191     elif arg in provided_args:
#     192         warn_deprecated_arg_usage(
#     193             arg, func.__name__, reason, version, stacklevel=3
#     194         )
# --> 196 return func(*args, **kwargs)
#
# File ~/.conda/envs/dsde-cedt/lib/python3.10/site-packages/redis/connection.py:2601, in ConnectionPool.get_connection(self, command_name, *keys, **options)
#    2597     self._in_use_connections.add(connection)
#    2599 try:
#    2600     # ensure this connection is connected to Redis
# -> 2601     connection.connect()
#    2602     # connections that the pool provides should be ready to send
#    2603     # a command. if not, the connection was either returned to the
#    2604     # pool before all data has been read or the socket has been
#    2605     # closed. either way, reconnect and verify everything is good.
#    2606     try:
#
# File ~/.conda/envs/dsde-cedt/lib/python3.10/site-packages/redis/connection.py:846, in AbstractConnection.connect(self)
#     844 def connect(self):
#     845     "Connects to the Redis server if not already connected"
# --> 846     self.connect_check_health(check_health=True)
#
# File ~/.conda/envs/dsde-cedt/lib/python3.10/site-packages/redis/connection.py:863, in AbstractConnection.connect_check_health(self, check_health, retry_socket_connect)
#     861     raise TimeoutError("Timeout connecting to server")
#     862 except OSError as e:
# --> 863     raise ConnectionError(self._error_message(e))
#     865 self._sock = sock
#     866 try:
#
# ConnectionError: Error 111 connecting to localhost:6379. Connection refused.

# %%
rd.get('user:101:name')

# %%
rd.hset('post:1', 'user', 101)
rd.hset('post:1', 'content', 'this is the first post')

# %%
rd.hgetall('post:1')

# %%
rd.rpush('user:101:post', 1)
rd.rpush('user:101:post', 8)

# %%
rd.llen('user:101:post')

# %%
rd.lrange('user:101:post', 0, -1)

# %%
rd.sadd('user:101:follows', 104)
rd.sadd('user:101:follows', 105)

# %%
rd.scard('user:101:follows')

# %%
rd.smembers('user:101:follows')

# %%
cursor = 0
cursor, keys = rd.scan(cursor=cursor, match='user:*')
while cursor > 0:
    for key in keys:
        print('found: ', key)
    cursor, keys = rd.scan(cursor=cursor, match='username:*')  

for key in keys:
    print('found: ', key)
